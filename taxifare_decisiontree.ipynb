# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import train_test_split
data=pd.read_csv('https://raw.githubusercontent.com/Premalatha-success/Datasets/main/TaxiFare.csv')
train, test = train_test_split(data,train_size = 0.7, test_size = 0.3)

# %%
train[pd.isnull(train)].sum()
# Out:
# unique_id                 0
# amount                  0.0
# date_time_of_pickup       0
# longitude_of_pickup     0.0
# latitude_of_pickup      0.0
# longitude_of_dropoff    0.0
# latitude_of_dropoff     0.0
# no_of_passenger         0.0
# dtype: object

# %%
train['date_time_of_pickup'] = pd.to_datetime(train['date_time_of_pickup'], format = '%Y-%m-%d %H:%M:%S UTC')

# %%
print (train.shape)
print (train.columns)
# Out:
# (35000, 8)
# Index(['unique_id', 'amount', 'date_time_of_pickup', 'longitude_of_pickup',
#        'latitude_of_pickup', 'longitude_of_dropoff', 'latitude_of_dropoff',
#        'no_of_passenger'],
#       dtype='object')

# %%
train=train.loc[train['amount']>=0]

print (train.shape)
# Out:
# (34997, 8)

# %%
print("Longitude Boundary in test data")
print (min(test.longitude_of_pickup.min(), test.longitude_of_dropoff.min()),max(test.longitude_of_pickup.max(), test.longitude_of_dropoff.max()))

print("Latitude Boundary in test data")
print (min(test.latitude_of_pickup.min(), test.latitude_of_pickup.min()),max(test.latitude_of_pickup.max(), test.latitude_of_pickup.max()))
# Out:
# Longitude Boundary in test data
# -75.42384832 40.851027
# Latitude Boundary in test data
# -74.004027 401.083332

# %%
print(len(train))
train.head()
# Out:
# 35000
#       unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 10119   57:16.0     4.5  2011-10-15 17:57:16 UTC           -73.955704
# 6021    35:58.0     6.5  2014-05-07 07:35:58 UTC           -73.991053
# 3827    28:00.0    11.0  2013-06-20 04:28:00 UTC            40.719830
# 25137   08:00.0     6.9  2010-06-09 23:08:00 UTC           -73.972742
# 32729   37:44.0     7.3  2009-05-21 21:37:44 UTC           -73.956352
#
#        latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 10119           40.776505            -73.962047            40.778847
# 6021            40.750792            -73.980527            40.760355
# 3827           -73.988467             40.723305           -73.939430
# 25137           40.756175            -73.954635            40.775522
# 32729           40.767186            -73.977515            40.782912
#
#        no_of_passenger
# 10119                1
# 6021                 1
# 3827                 1
# ...

# %%
X_test = test.iloc[:,2:]
Xt = train.iloc[:5,3:]
X_test = X_test[Xt.columns]
Xt.head()
X_test.head()
import gc
gc.collect()
# Out:
# 264

# %%
len(train)
# Out:
# 35000

# %%
X_test2 = train.iloc[3500:,:]
X_test2 = X_test2[Xt.columns]

# %%
for i in tqdm(range(len(train)//1000)):
    df_chunk = train.iloc[i*10**3:(i+1)*10**3, :]
    X = df_chunk.iloc[:,3:]
    y = df_chunk['amount']
# Out:
# 100%|██████████| 35/35 [00:00<00:00, 1677.61it/s]

# %%
from sklearn.tree import DecisionTreeRegressor 

regressor = DecisionTreeRegressor(random_state = 0) 
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=0)
